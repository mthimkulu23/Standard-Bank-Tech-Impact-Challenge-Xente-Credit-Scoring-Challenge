# %% [markdown]
# <a href="https://colab.research.google.com/github/mthimkulu23/Standard-Bank-Tech-Impact-Challenge-Xente-Credit-Scoring-Challenge/blob/main/Standard_Bank_Tech_Impact_Challenge_Xente_Credit_Scoring_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#  Load data
Train = pd.read_csv('Train.csv')
Train

# check_duplicates = Train.duplicated().sum()
# check_duplicates


# Train.isnull().sum()
# Out:
#           CustomerId TransactionStartTime   Value  Amount       TransactionId  \
# 0      CustomerId_27  2018-09-21 12:17:39   550.0  -550.0  TransactionId_1683
# 1      CustomerId_27  2018-09-25 09:20:29   550.0  -550.0  TransactionId_2235
# 2      CustomerId_27  2018-09-25 10:33:31   550.0  -550.0  TransactionId_1053
# 3      CustomerId_27  2018-09-27 10:26:41  1000.0 -1000.0  TransactionId_2633
# 4      CustomerId_27  2018-09-27 12:44:21   500.0  -500.0    TransactionId_71
# ...              ...                  ...     ...     ...                 ...
# 2095   CustomerId_28  2019-03-30 21:55:11  2000.0 -2000.0  TransactionId_1185
# 2096   CustomerId_28  2019-03-30 23:54:07  5000.0 -5000.0  TransactionId_1824
# 2097   CustomerId_34  2019-03-31 05:40:10  5000.0 -5000.0  TransactionId_2507
# 2098  CustomerId_346  2019-03-31 09:37:19  1500.0 -1500.0   TransactionId_540
# 2099  CustomerId_188  2019-03-31 12:16:33  1000.0 -1000.0  TransactionId_1889
#
# ...

# %%
#  Load data
test = pd.read_csv('Test.csv')
test

# check_duplicates = test.duplicated().sum()
# check_duplicates

# test.isnull().sum()
# Out:
#          CustomerId TransactionStartTime    Value   Amount  \
# 0    CustomerId_310  2019-03-31 13:33:05  14000.0 -14000.0
# 1    CustomerId_243  2019-03-31 15:04:09   1000.0  -1000.0
# 2    CustomerId_142  2019-03-31 17:31:11   2500.0  -2500.0
# 3    CustomerId_142  2019-03-31 17:32:15    500.0   -500.0
# 4    CustomerId_142  2019-03-31 17:34:41   1000.0  -1000.0
# ..              ...                  ...      ...      ...
# 900  CustomerId_412  2019-07-16 00:18:46    500.0   -500.0
# 901  CustomerId_326  2019-07-16 03:17:01   1000.0  -1000.0
# 902  CustomerId_497  2019-07-16 15:06:22   1000.0  -1000.0
# 903  CustomerId_497  2019-07-16 15:09:58    800.0   -800.0
# 904  CustomerId_372  2019-07-17 05:34:45   1900.0  -1900.0
#
#           TransactionId       BatchId    SubscriptionId CurrencyCode  \
# 0     TransactionId_925  BatchId_1144  SubscriptionId_7          UGX
# 1    TransactionId_1080  BatchId_1214  SubscriptionId_7          UGX
# ...

# %%
#  Load data
unlinked_masked = pd.read_csv('unlinked_masked_final.csv')
unlinked_masked

# check_duplicates = unlinked_masked.duplicated().sum()
# check_duplicates

# unlinked_masked.isnull().sum()
# Out:
#              TransactionId        BatchId      CustomerId CurrencyCode  \
# 0      TransactionId_18876   BatchId_7899  CustomerId_250          UGX
# 1      TransactionId_15089   BatchId_8829  CustomerId_423          UGX
# 2       TransactionId_9561  BatchId_15250  CustomerId_423          UGX
# 3       TransactionId_3635  BatchId_14442  CustomerId_316          UGX
# 4       TransactionId_3104   BatchId_5171  CustomerId_193          UGX
# ...                    ...            ...             ...          ...
# 16322  TransactionId_11472  BatchId_12998  CustomerId_282          UGX
# 16323  TransactionId_18689  BatchId_10292  CustomerId_282          UGX
# 16324  TransactionId_17879  BatchId_16972  CustomerId_282          UGX
# 16325   TransactionId_6532  BatchId_11541  CustomerId_180          UGX
# 16326  TransactionId_16784  BatchId_11840  CustomerId_310          UGX
#
#        CountryCode    ProviderId     ProductId     ProductCategory  \
# ...

# %%
#merging dataset for train
merge_train = Train.merge(unlinked_masked, how="inner", on = "CustomerId")
merge_train
# Out:
#             CustomerId TransactionStartTime_x  Value_x  Amount_x  \
# 0        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 1        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 2        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 3        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 4        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# ...                ...                    ...      ...       ...
# 130055  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130056  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130057  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130058  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130059  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
#
#            TransactionId_x    BatchId_x    SubscriptionId CurrencyCode_x  \
# 0       TransactionId_1683  BatchId_641  SubscriptionId_2            UGX
# ...

# %%
#merging dataset for test
merge_test = test.merge(unlinked_masked, how="inner", on = "CustomerId")
merge_test
# Out:
#            CustomerId TransactionStartTime_x  Value_x  Amount_x  \
# 0      CustomerId_310    2019-03-31 13:33:05  14000.0  -14000.0
# 1      CustomerId_310    2019-03-31 13:33:05  14000.0  -14000.0
# 2      CustomerId_310    2019-03-31 13:33:05  14000.0  -14000.0
# 3      CustomerId_310    2019-03-31 13:33:05  14000.0  -14000.0
# 4      CustomerId_310    2019-03-31 13:33:05  14000.0  -14000.0
# ...               ...                    ...      ...       ...
# 73508  CustomerId_326    2019-07-16 03:17:01   1000.0   -1000.0
# 73509  CustomerId_326    2019-07-16 03:17:01   1000.0   -1000.0
# 73510  CustomerId_326    2019-07-16 03:17:01   1000.0   -1000.0
# 73511  CustomerId_326    2019-07-16 03:17:01   1000.0   -1000.0
# 73512  CustomerId_326    2019-07-16 03:17:01   1000.0   -1000.0
#
#           TransactionId_x     BatchId_x    SubscriptionId CurrencyCode_x  \
# 0       TransactionId_925  BatchId_1144  SubscriptionId_7            UGX
# ...

# %%
variable_definition = pd.read_csv('VariableDefinitions.csv')
variable_definition
# Out:
#                  Variable                                         Definition
# 0              CustomerId  Unique number identifying the customer on plat...
# 1    TransactionStartTime                             Transaction start time
# 2                   Value                               Value of transaction
# 3                  Amount                  Value of Transaction with charges
# 4           TransactionId          Unique transaction identifier on platform
# 5                 BatchId  Identifier for bulk transactions being done on...
# 6          SubscriptionId  You can have one account with multiple subscri...
# 7            CurrencyCode                                   Country currency
# 8             CountryCode             Numerical geographical code of country
# 9              ProviderId                     Source provider of Item bought
# 10              ProductId                             Item name being bought
# ...

# %%
check_duplicates = merge_train.isnull().sum()
check_duplicates
# Out:
# CustomerId                    0
# TransactionStartTime_x        0
# Value_x                       0
# Amount_x                      0
# TransactionId_x               0
# BatchId_x                     0
# SubscriptionId                0
# CurrencyCode_x                0
# CountryCode_x                 0
# ProviderId_x                  0
# ProductId_x                   0
# ProductCategory_x             0
# ChannelId_x                   0
# TransactionStatus             0
# IssuedDateLoan            11736
# AmountLoan                11736
# Currency                  11736
# LoanId                    11736
# PaidOnDate                11736
# IsFinalPayBack            11736
# InvestorId                11736
# DueDate                   11925
# LoanApplicationId         12125
# PayBackId                 11736
# ThirdPartyId              11736
# IsThirdPartyConfirmed     11736
# IsDefaulted               11736
# TransactionId_y               0
# BatchId_y                     0
# ...

# %%
fill_nulls_train = merge_train.fillna("Unknown")
fill_nulls_train

# check_duplicates = fill_nulls_train.isnull().sum()
# check_duplicates
# Out:
# CustomerId                0
# TransactionStartTime_x    0
# Value_x                   0
# Amount_x                  0
# TransactionId_x           0
# BatchId_x                 0
# SubscriptionId            0
# CurrencyCode_x            0
# CountryCode_x             0
# ProviderId_x              0
# ProductId_x               0
# ProductCategory_x         0
# ChannelId_x               0
# TransactionStatus         0
# IssuedDateLoan            0
# AmountLoan                0
# Currency                  0
# LoanId                    0
# PaidOnDate                0
# IsFinalPayBack            0
# InvestorId                0
# DueDate                   0
# LoanApplicationId         0
# PayBackId                 0
# ThirdPartyId              0
# IsThirdPartyConfirmed     0
# IsDefaulted               0
# TransactionId_y           0
# BatchId_y                 0
# CurrencyCode_y            0
# CountryCode_y             0
# ProviderId_y              0
# ProductId_y               0
# ...

# %%
check_duplicates = merge_test.isnull().sum()
check_duplicates


fill_null_test = merge_test.fillna("Unknown")
fill_null_test


check_dupli = fill_null_test.isnull().sum()
check_dupli
# Out:
# CustomerId                0
# TransactionStartTime_x    0
# Value_x                   0
# Amount_x                  0
# TransactionId_x           0
# BatchId_x                 0
# SubscriptionId            0
# CurrencyCode_x            0
# CountryCode_x             0
# ProviderId_x              0
# ProductId_x               0
# ProductCategory_x         0
# ChannelId_x               0
# TransactionStatus         0
# IssuedDateLoan            0
# LoanId                    0
# InvestorId                0
# LoanApplicationId         0
# ThirdPartyId              0
# TransactionId_y           0
# BatchId_y                 0
# CurrencyCode_y            0
# CountryCode_y             0
# ProviderId_y              0
# ProductId_y               0
# ProductCategory_y         0
# ChannelId_y               0
# Amount_y                  0
# Value_y                   0
# TransactionStartTime_y    0
# dtype: int64

# %%
drop_target = fill_nulls_train.drop('IsDefaulted', axis=1)
drop_target
# Out:
#             CustomerId TransactionStartTime_x  Value_x  Amount_x  \
# 0        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 1        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 2        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 3        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# 4        CustomerId_27    2018-09-21 12:17:39    550.0    -550.0
# ...                ...                    ...      ...       ...
# 130055  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130056  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130057  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130058  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
# 130059  CustomerId_188    2019-03-31 12:16:33   1000.0   -1000.0
#
#            TransactionId_x    BatchId_x    SubscriptionId CurrencyCode_x  \
# 0       TransactionId_1683  BatchId_641  SubscriptionId_2            UGX
# ...

# %%
y = fill_nulls_train['IsDefaulted']
y
# Out:
# 0         Unknown
# 1         Unknown
# 2         Unknown
# 3         Unknown
# 4         Unknown
#            ...
# 130055        0.0
# 130056        0.0
# 130057        0.0
# 130058        0.0
# 130059        0.0
# Name: IsDefaulted, Length: 130060, dtype: object

# %%
x = drop_target.drop(["TransactionStartTime_y","TransactionStartTime_x", "CustomerId", "PaidOnDate", "DueDate"],axis = 1)
x
# Out:
#         Value_x  Amount_x     TransactionId_x    BatchId_x    SubscriptionId  \
# 0         550.0    -550.0  TransactionId_1683  BatchId_641  SubscriptionId_2
# 1         550.0    -550.0  TransactionId_1683  BatchId_641  SubscriptionId_2
# 2         550.0    -550.0  TransactionId_1683  BatchId_641  SubscriptionId_2
# 3         550.0    -550.0  TransactionId_1683  BatchId_641  SubscriptionId_2
# 4         550.0    -550.0  TransactionId_1683  BatchId_641  SubscriptionId_2
# ...         ...       ...                 ...          ...               ...
# 130055   1000.0   -1000.0  TransactionId_1889  BatchId_355  SubscriptionId_7
# 130056   1000.0   -1000.0  TransactionId_1889  BatchId_355  SubscriptionId_7
# 130057   1000.0   -1000.0  TransactionId_1889  BatchId_355  SubscriptionId_7
# 130058   1000.0   -1000.0  TransactionId_1889  BatchId_355  SubscriptionId_7
# 130059   1000.0   -1000.0  TransactionId_1889  BatchId_355  SubscriptionId_7
#
# ...
